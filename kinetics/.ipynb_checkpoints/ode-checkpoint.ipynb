# %%
import os
os.chdir('advancesyntoolkit-master')
import astools
import importlib

# %%
modelfile = "/Users/sam/Documents/Research/transfoam/kinetics/advancesyntoolkit-master/models/asm/ecoJC20.modelspec"

astools.generateODEScript(modelfile, mtype='ASM', solver='RK4', 
                      timestep=1, endtime=21600, 
                      lowerbound='0;0', 
                      upperbound='1e-3;1e-3',
                      odefile='odescript.py')
# Out:
# ["''' -------------------------------------",
#  'Python ODE script generated by ASModeller',
#  '(a package in AdvanceSynToolKit)',
#  '',
#  'Date Time: 2022-4-4 22:3:3:847718',
#  '',
#  'name: Escherichia coli specific kinetic model (ecoJC20)',
#  'authors: Jeremy L Cho, Maurice HT Ling',
#  'description: Adaptation from UniKin1',
#  "------------------------------------- '''",
#  '',
#  'def C00001(t, y):',
#  '    R11 = (10 * 0.045764766 * y[83] * y[9] )/(0.001 + 0.045764766 * y[83] * y[9] )',
#  '    R15 = (10 * 0.1 * y[83] * y[9])/(0.001 + 0.1 * y[83] * y[9])',
#  '    R17 = (10 * 4.520812769 * y[83] )/(0.001 + 4.520812769 * y[83] )',
#  '    R19 = (10 * 4.520812769 * y[110] )/(0.001 + 4.520812769 * y[110] )',
#  '    R48 = (10 * 0.010698511 * y[79] )/(0.001 + 0.010698511 * y[79] )',
#  '    R65 = (10 * 0.1 * y[20] * y[13] * y[3] * y[47])/(0.001 + 0.1 * y[20] * y[13] * y[3] * y[47])',
# ...

# %%
odefile = '/Users/sam/Documents/Research/transfoam/kinetics/advancesyntoolkit-master/odescript/odescript.py'

runODEScript(odefile, sampling=100, resultfile='oderesult.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
#       1 odefile = '/Users/sam/Documents/Research/transfoam/kinetics/advancesyntoolkit-master/odescript/odescript.py'
# ----> 3 runODEScript(odefile, sampling=100, resultfile='oderesult.csv')
#
# Input In [3], in runODEScript(odefile, sampling, resultfile)
#       4 '''!
#       5 Function to run / execute the ODE model and write out the
#       6 simulation results.
#    (...)
#      19 write out simulation results. Default = 'oderesult.csv'
#      20 '''
#      21 odefile = os.path.splitext(odefile)[0]
# ---> 22 m = importlib.import_module('odescript.'+ odefile)
#      23 resultfile = os.path.abspath(resultfile)
#      24 print('Executing ODE model - %s in odescript folder' % odefile)
#
# NameError: name 'importlib' is not defined
